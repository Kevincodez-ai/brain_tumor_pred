# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevincodez-ai/brain_tumor_pred/blob/main/model_training_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
import zipfile
import os

zip_path = '/content/brain_test_dataset.zip'  # Replace with your file name
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('dataset')  # Extract into a folder called "dataset"

# Check what’s inside
os.listdir('dataset')
# Out:
# ['brain_test_dataset']

# %%
train_dir = '/content/dataset/brain_test_dataset/brain_tumor_dataset/train'

# %%
test_dir = '/content/dataset/brain_test_dataset/brain_tumor_dataset/test'

# %%
train_datagen = ImageDataGenerator(rescale = 1./255 , zoom_range = 0.2  , rotation_range = 15 , horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale = 1./255)
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size = (224 , 224),
    batch_size = 32 ,
    class_mode = 'binary'
)
test_data = train_datagen.flow_from_directory(
    test_dir,
    target_size = (224 , 224),
    batch_size = 32 ,
    class_mode = 'binary'
)
# Out:
# Found 180 images belonging to 2 classes.
# Found 73 images belonging to 2 classes.

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
  layer.trainable = False # freeze the layer
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128 , activation = 'relu')(x)
x = Dropout(0.5)(x)
ouput = Dense(1 , activation='sigmoid')(x)
model = Model(inputs = base_model.input , outputs = ouput)

# %%
model.compile(
    optimizer = 'Adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_data ,
    validation_data = test_data,
    epochs =10
)
model.save("enhanced braintumor detection.h5")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 61s 9s/step - accuracy: 0.4250 - loss: 0.8730 - val_accuracy: 0.6438 - val_loss: 0.6746
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 54s 10s/step - accuracy: 0.5963 - loss: 0.7463 - val_accuracy: 0.6849 - val_loss: 0.6354
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 48s 9s/step - accuracy: 0.6383 - loss: 0.6623 - val_accuracy: 0.6986 - val_loss: 0.6096
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 47s 8s/step - accuracy: 0.6773 - loss: 0.6484 - val_accuracy: 0.7123 - val_loss: 0.5989
# Epoch 5/10
# ...
